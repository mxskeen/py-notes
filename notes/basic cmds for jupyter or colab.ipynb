# %%
#basic cmds for jupyter or colab

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 165
# model name	: Intel(R) Core(TM) i5-10500H CPU @ 2.50GHz
# stepping	: 2
# microcode	: 0xf6
# cpu MHz		: 4299.134
# cache size	: 12288 KB
# physical id	: 0
# siblings	: 12
# core id		: 0
# cpu cores	: 6
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 22
# wp		: yes
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:        8038352 kB
# MemFree:          870064 kB
# MemAvailable:    3578896 kB
# Buffers:               8 kB
# Cached:          2920660 kB
# SwapCached:          228 kB
# Active:          5597832 kB
# Inactive:         370884 kB
# Active(anon):    2986048 kB
# Inactive(anon):   228408 kB
# Active(file):    2611784 kB
# Inactive(file):   142476 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:       8037372 kB
# SwapFree:        8017188 kB
# Zswap:                 0 kB
# Zswapped:              0 kB
# Dirty:              3296 kB
# Writeback:             0 kB
# AnonPages:       3023348 kB
# Mapped:          1365172 kB
# Shmem:            166620 kB
# KReclaimable:     261652 kB
# Slab:             492880 kB
# SReclaimable:     261652 kB
# SUnreclaim:       231228 kB
# KernelStack:       17088 kB
# PageTables:        44568 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# ...
